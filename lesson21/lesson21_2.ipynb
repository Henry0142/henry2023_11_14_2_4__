# %%
import numpy as np
import pandas as pd

df = pd.DataFrame({'key1':['a', 'a', 'b', 'b', 'a'],
                  'key2':['one', 'two', 'one', 'two', 'one'],
                  'data1': np.random.randn(5),
                  'data2':np.random.randn(5)})
df
# Out:
#   key1 key2     data1     data2
# 0    a  one -0.275027  1.927118
# 1    a  two  2.040315  1.401665
# 2    b  one -1.830520  0.832444
# 3    b  two -0.137960  0.235530
# 4    a  one -0.067819  0.014434

# %%
df1 = df.set_index(keys=['key1','key2'])
df1
# Out:
#               data1     data2
# key1 key2
# a    one  -0.275027  1.927118
#      two   2.040315  1.401665
# b    one  -1.830520  0.832444
#      two  -0.137960  0.235530
# a    one  -0.067819  0.014434

# %%
df1.columns.name = 'data'
df1
# Out:
# data          data1     data2
# key1 key2
# a    one  -0.275027  1.927118
#      two   2.040315  1.401665
# b    one  -1.830520  0.832444
#      two  -0.137960  0.235530
# a    one  -0.067819  0.014434

# %%
df2 = df1.groupby(level=['key1','key2']).mean()
df2
# Out:
# data          data1     data2
# key1 key2
# a    one  -0.171423  0.970776
#      two   2.040315  1.401665
# b    one  -1.830520  0.832444
#      two  -0.137960  0.235530

# %%
df2.unstack(level='key1')
# Out:
# data     data1              data2
# key1         a        b         a         b
# key2
# one  -0.171423 -1.83052  0.970776  0.832444
# two   2.040315 -0.13796  1.401665  0.235530
